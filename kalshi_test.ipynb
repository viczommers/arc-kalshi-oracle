# %% [markdown]
# ## Get todays market

# %%
import requests
from datetime import datetime, timedelta, timezone

def get_todays_maket():
    tomorrow_utc = datetime.now(timezone.utc) + timedelta(hours=24)
    tomorrow_timestamp = int(tomorrow_utc.timestamp())
    try:
        url = "https://api.elections.kalshi.com/trade-api/v2/markets"
        url = "https://demo-api.kalshi.co/trade-api/v2/events"
        querystring = {
            "series_ticker":"KXEURUSD",
            "status": "open",
            "with_nested_markets":True,
            "min_close_ts": tomorrow_timestamp
            }
        response = requests.get(url, params=querystring)
        response.raise_for_status()
        result = response.json()
        markets = result.get('events',[])
        if markets:
            # return markets[0]
            # Sort by expected_expiration_time (earliest first)
            sorted_markets = sorted(
                markets,
                key=lambda x: x.get('expected_expiration_time', '9999-12-31T23:59:59Z')
            )
            return sorted_markets[0]
            
    except Exception as e:
        print("Error ", e)
        return None

market_id = get_todays_maket()
market_id
# Out:
# {'available_on_brokers': False,
#  'category': 'Financials',
#  'collateral_return_type': 'MECNET',
#  'event_ticker': 'KXEURUSD-25NOV1710',
#  'markets': [{'can_close_early': True,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.17599,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 100,
#    'no_bid_dollars': '1.0000',
#    'no_sub_title': '1.17600 or above',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is above 1.17599 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'greater',
#    'subtitle': '1.17600 or above',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-T1.17599',
#    'title': 'Will the EUR/USD open price be above 1.17599 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 0,
#    'yes_ask_dollars': '0.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.17600 or above'},
#   {'can_close_early': True,
#    'cap_strike': 1.15,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.1499899999999998 or below',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is below 1.15000 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'less',
#    'subtitle': '1.1499899999999998 or below',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-T1.15000',
#    'title': 'Will the EUR/USD open price be below 1.15000 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.1499899999999998 or below'},
#   {'can_close_early': True,
#    'cap_strike': 1.17599,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.174,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 100,
#    'no_bid_dollars': '1.0000',
#    'no_sub_title': '1.17400 to 1.17599',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.17400-1.17599 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.17400 to 1.17599',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.175',
#    'title': 'Will the EUR/USD open price be between 1.17400 and 1.17599 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 0,
#    'yes_ask_dollars': '0.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.17400 to 1.17599'},
#   {'can_close_early': True,
#    'cap_strike': 1.17399,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.172,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 100,
#    'no_bid_dollars': '1.0000',
#    'no_sub_title': '1.17200 to 1.17399',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.17200-1.17399 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.17200 to 1.17399',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.173',
#    'title': 'Will the EUR/USD open price be between 1.17200 and 1.17399 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 0,
#    'yes_ask_dollars': '0.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.17200 to 1.17399'},
#   {'can_close_early': True,
#    'cap_strike': 1.17199,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.17,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 100,
#    'no_bid_dollars': '1.0000',
#    'no_sub_title': '1.17000 to 1.17199',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.17000-1.17199 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.17000 to 1.17199',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.171',
#    'title': 'Will the EUR/USD open price be between 1.17000 and 1.17199 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 0,
#    'yes_ask_dollars': '0.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.17000 to 1.17199'},
#   {'can_close_early': True,
#    'cap_strike': 1.16999,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.168,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 100,
#    'no_bid_dollars': '1.0000',
#    'no_sub_title': '1.16800 to 1.16999',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.16800-1.16999 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.16800 to 1.16999',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.169',
#    'title': 'Will the EUR/USD open price be between 1.16800 and 1.16999 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 0,
#    'yes_ask_dollars': '0.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.16800 to 1.16999'},
#   {'can_close_early': True,
#    'cap_strike': 1.16799,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.166,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 100,
#    'no_bid_dollars': '1.0000',
#    'no_sub_title': '1.16600 to 1.16799',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.16600-1.16799 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.16600 to 1.16799',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.167',
#    'title': 'Will the EUR/USD open price be between 1.16600 and 1.16799 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 0,
#    'yes_ask_dollars': '0.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.16600 to 1.16799'},
#   {'can_close_early': True,
#    'cap_strike': 1.16599,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.164,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 9000,
#    'liquidity_dollars': '90.0000',
#    'market_type': 'binary',
#    'no_ask': 90,
#    'no_ask_dollars': '0.9000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.16400 to 1.16599',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.16400-1.16599 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.16400 to 1.16599',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.165',
#    'title': 'Will the EUR/USD open price be between 1.16400 and 1.16599 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 10,
#    'yes_bid_dollars': '0.1000',
#    'yes_sub_title': '1.16400 to 1.16599'},
#   {'can_close_early': True,
#    'cap_strike': 1.16399,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.162,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 1000,
#    'liquidity_dollars': '10.0000',
#    'market_type': 'binary',
#    'no_ask': 10,
#    'no_ask_dollars': '0.1000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.16200 to 1.16399',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.16200-1.16399 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.16200 to 1.16399',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.163',
#    'title': 'Will the EUR/USD open price be between 1.16200 and 1.16399 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 90,
#    'yes_bid_dollars': '0.9000',
#    'yes_sub_title': '1.16200 to 1.16399'},
#   {'can_close_early': True,
#    'cap_strike': 1.16199,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.16,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 6000,
#    'liquidity_dollars': '60.0000',
#    'market_type': 'binary',
#    'no_ask': 60,
#    'no_ask_dollars': '0.6000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.16000 to 1.16199',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.16000-1.16199 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.16000 to 1.16199',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.161',
#    'title': 'Will the EUR/USD open price be between 1.16000 and 1.16199 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 40,
#    'yes_bid_dollars': '0.4000',
#    'yes_sub_title': '1.16000 to 1.16199'},
#   {'can_close_early': True,
#    'cap_strike': 1.15999,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.158,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 8000,
#    'liquidity_dollars': '80.0000',
#    'market_type': 'binary',
#    'no_ask': 80,
#    'no_ask_dollars': '0.8000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.15800 to 1.15999',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.15800-1.15999 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.15800 to 1.15999',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.159',
#    'title': 'Will the EUR/USD open price be between 1.15800 and 1.15999 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 20,
#    'yes_bid_dollars': '0.2000',
#    'yes_sub_title': '1.15800 to 1.15999'},
#   {'can_close_early': True,
#    'cap_strike': 1.15799,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.156,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.15600 to 1.15799',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.15600-1.15799 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.15600 to 1.15799',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.157',
#    'title': 'Will the EUR/USD open price be between 1.15600 and 1.15799 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.15600 to 1.15799'},
#   {'can_close_early': True,
#    'cap_strike': 1.15599,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.154,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.15400 to 1.15599',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.15400-1.15599 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.15400 to 1.15599',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.155',
#    'title': 'Will the EUR/USD open price be between 1.15400 and 1.15599 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.15400 to 1.15599'},
#   {'can_close_early': True,
#    'cap_strike': 1.15399,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.152,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.15200 to 1.15399',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.15200-1.15399 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.15200 to 1.15399',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.153',
#    'title': 'Will the EUR/USD open price be between 1.15200 and 1.15399 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.15200 to 1.15399'},
#   {'can_close_early': True,
#    'cap_strike': 1.15199,
#    'category': '',
#    'close_time': '2025-11-17T15:00:00Z',
#    'created_time': '0001-01-01T00:00:00Z',
#    'event_ticker': 'KXEURUSD-25NOV1710',
#    'expected_expiration_time': '2025-11-17T15:00:00Z',
#    'expiration_time': '2025-11-24T15:00:00Z',
#    'expiration_value': '',
#    'floor_strike': 1.15,
#    'last_price': 0,
#    'last_price_dollars': '0.0000',
#    'latest_expiration_time': '2025-11-24T15:00:00Z',
#    'liquidity': 0,
#    'liquidity_dollars': '0.0000',
#    'market_type': 'binary',
#    'no_ask': 100,
#    'no_ask_dollars': '1.0000',
#    'no_bid': 0,
#    'no_bid_dollars': '0.0000',
#    'no_sub_title': '1.15000 to 1.15199',
#    'notional_value': 100,
#    'notional_value_dollars': '1.0000',
#    'open_interest': 0,
#    'open_time': '2025-11-14T10:58:33Z',
#    'previous_price': 0,
#    'previous_price_dollars': '0.0000',
#    'previous_yes_ask': 0,
#    'previous_yes_ask_dollars': '0.0000',
#    'previous_yes_bid': 0,
#    'previous_yes_bid_dollars': '0.0000',
#    'price_level_structure': 'linear_cent',
#    'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#    'response_price_units': 'usd_cent',
#    'result': None,
#    'risk_limit_cents': 0,
#    'rules_primary': 'If the open price of the Euro/Dollar for November 17, 2025 is between 1.15000-1.15199 at 10 AM EST, then the market resolves to Yes.',
#    'rules_secondary': '',
#    'settlement_timer_seconds': 60,
#    'status': 'active',
#    'strike_type': 'between',
#    'subtitle': '1.15000 to 1.15199',
#    'tick_size': 1,
#    'ticker': 'KXEURUSD-25NOV1710-B1.151',
#    'title': 'Will the EUR/USD open price be between 1.15000 and 1.15199 at Nov 17, 2025 at 10am EST?',
#    'volume': 0,
#    'volume_24h': 0,
#    'yes_ask': 100,
#    'yes_ask_dollars': '1.0000',
#    'yes_bid': 0,
#    'yes_bid_dollars': '0.0000',
#    'yes_sub_title': '1.15000 to 1.15199'}],
#  'mutually_exclusive': True,
#  'series_ticker': 'KXEURUSD',
#  'strike_date': '2025-11-17T15:00:00Z',
#  'strike_period': '',
#  'sub_title': 'Nov 17, 2025 at 10am EST',
#  'title': 'EUR/USD price range on Monday at 10am EST?'}
